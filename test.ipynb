# %%
import extract
print(extract.__file__)
# Out:
# c:\work\data-migration-aparna\extract.py

# %%
from extract import extract

# %%
customers_df = extract("customers")

# %%
customers_df.head()
# Out:
#   customer_id                                            profile  \
# 0     CUST001  {'name': 'Customer_1', 'email': 'customer1@exa...
# 1     CUST002  {'name': 'Customer_2', 'email': 'customer2@exa...
# 2     CUST003  {'name': 'Customer_3', 'email': 'customer3@exa...
# 3     CUST004  {'name': 'Customer_4', 'email': 'customer4@exa...
# 4     CUST005  {'name': 'Customer_5', 'email': 'customer5@exa...
#
#                                              address  \
# 0  {'current': {'street': 'Street 112', 'city': '...
# 1  {'current': {'street': 'Street 83', 'city': 'H...
# 2  {'current': {'street': 'Street 125', 'city': '...
# 3  {'current': {'street': 'Street 88', 'city': 'K...
# 4  {'current': {'street': 'Street 4', 'city': 'Ko...
#
#                                      payment_methods  \
# 0  [{'method': 'Credit Card', 'provider': 'ICICI'...
# 1  [{'method': 'Credit Card', 'provider': 'HDFC',...
# 2  [{'method': 'Debit Card', 'provider': 'SBI', '...
# 3  [{'method': 'UPI', 'provider': 'SBI', 'last_us...
# 4  [{'method': 'Debit Card', 'provider': 'HDFC', ...
#
#                  last_updated
# 0  2026-02-26T04:20:23.360672
# 1  2026-02-26T13:20:23.360728
# 2  2026-02-24T04:20:23.360752
# 3  2026-02-23T08:20:23.360773
# 4  2026-02-20T10:20:23.360790

# %%
orders_df = extract("orders")

# %%
orders_df
# Out:
#      order_id customer_id seller_id                  order_date order_status  \
# 0     ORD0001     CUST173   SELL068  2026-02-15T14:30:28.025493    DELIVERED
# 1     ORD0002     CUST110   SELL035  2026-02-11T14:30:28.025584    CANCELLED
# 2     ORD0003     CUST429   SELL017  2026-02-07T14:30:28.025646       PLACED
# 3     ORD0004     CUST344   SELL029  2026-02-11T14:30:28.025703       PLACED
# 4     ORD0005     CUST437   SELL056  2026-02-14T14:30:28.025751       PLACED
# ...       ...         ...       ...                         ...          ...
# 1495  ORD1496     CUST212   SELL102  2026-01-29T14:30:28.074240      SHIPPED
# 1496  ORD1497     CUST113   SELL084  2026-02-14T14:30:28.074276    DELIVERED
# 1497  ORD1498     CUST340   SELL048  2026-02-21T14:30:28.074306    CANCELLED
# 1498  ORD1499     CUST335   SELL067  2026-01-31T14:30:28.074331    CANCELLED
# 1499  ORD1500     CUST307   SELL080  2026-02-03T14:30:28.074352    CANCELLED
#
#                                                   items  \
# 0     [{'product_id': 'PRD426', 'product_name': 'Clo...
# 1     [{'product_id': 'PRD134', 'product_name': 'Clo...
# 2     [{'product_id': 'PRD756', 'product_name': 'Clo...
# 3     [{'product_id': 'PRD915', 'product_name': 'Boo...
# 4     [{'product_id': 'PRD651', 'product_name': 'Clo...
# ...                                                 ...
# 1495  [{'product_id': 'PRD247', 'product_name': 'Clo...
# 1496  [{'product_id': 'PRD810', 'product_name': 'Hom...
# 1497  [{'product_id': 'PRD363', 'product_name': 'Hom...
# 1498  [{'product_id': 'PRD875', 'product_name': 'Boo...
# 1499  [{'product_id': 'PRD436', 'product_name': 'Ele...
#
#                                                 payment  \
# 0     {'method': 'UPI', 'transaction_id': 'TXN564118...
# 1     {'method': 'UPI', 'transaction_id': 'TXN294309...
# 2     {'method': 'Credit Card', 'transaction_id': 'T...
# 3     {'method': 'UPI', 'transaction_id': 'TXN455540...
# 4     {'method': 'UPI', 'transaction_id': 'TXN680412...
# ...                                                 ...
# 1495  {'method': 'UPI', 'transaction_id': 'TXN604123...
# 1496  {'method': 'Debit Card', 'transaction_id': Non...
# 1497  {'method': 'Debit Card', 'transaction_id': 'TX...
# 1498  {'method': 'Debit Card', 'transaction_id': 'TX...
# 1499  {'method': 'UPI', 'transaction_id': 'TXN595317...
#
#                                                shipping  order_total  \
# 0     {'delivery_partner': 'Delhivery', 'expected_de...     66057.93
# 1     {'delivery_partner': None, 'expected_delivery'...     70345.25
# 2     {'delivery_partner': 'Delhivery', 'expected_de...     26484.62
# 3     {'delivery_partner': 'Delhivery', 'expected_de...    125493.68
# 4     {'delivery_partner': 'Delhivery', 'expected_de...     54059.38
# ...                                                 ...          ...
# 1495  {'delivery_partner': 'Delhivery', 'expected_de...     28465.30
# 1496  {'delivery_partner': 'Ecom Express', 'expected...    115995.38
# 1497  {'delivery_partner': 'Ecom Express', 'expected...    124713.88
# 1498  {'delivery_partner': 'Delhivery', 'expected_de...      3095.16
# 1499  {'delivery_partner': 'Ecom Express', 'expected...     19629.21
#
#                     last_updated
# 0     2026-02-17T05:30:28.025493
# 1     2026-02-12T06:30:28.025584
# 2     2026-02-08T01:30:28.025646
# 3     2026-02-13T06:30:28.025703
# 4     2026-02-15T03:30:28.025751
# ...                          ...
# 1495  2026-01-30T02:30:28.074240
# 1496  2026-02-14T17:30:28.074276
# 1497  2026-02-21T21:30:28.074306
# 1498  2026-02-01T15:30:28.074331
# 1499  2026-02-04T06:30:28.074352
#
# [1500 rows x 10 columns]

# %%
sellers_df=extract("sellers")

# %%
sellers_df.head()
# Out:
#   seller_id                                     seller_profile  \
# 0   SELL001  {'name': 'Seller_1', 'business_type': 'Wholesa...
# 1   SELL002  {'name': 'Seller_2', 'business_type': None, 'j...
# 2   SELL003  {'name': 'Seller_3', 'business_type': 'Retail'...
# 3   SELL004  {'name': 'Seller_4', 'business_type': 'Retail'...
# 4   SELL005  {'name': 'Seller_5', 'business_type': 'Retail'...
#
#                                              address  \
# 0  {'street': 'Shop 155', 'city': 'Pune', 'state'...
# 1  {'street': 'Shop 280', 'city': 'Delhi', 'state...
# 2  {'street': 'Shop 298', 'city': 'Kolkata', 'sta...
# 3  {'street': 'Shop 83', 'city': 'Mumbai', 'state...
# 4  {'street': 'Shop 217', 'city': 'Pune', 'state'...
#
#                                             products  \
# 0  [{'product_id': 'PRD866', 'category': 'Electro...
# 1  [{'product_id': 'PRD528', 'category': 'Books',...
# 2  [{'product_id': 'PRD555', 'category': 'Clothin...
# 3  [{'product_id': 'PRD833', 'category': 'Books',...
# 4  [{'product_id': 'PRD831', 'category': 'Books',...
#
#                                              ratings  \
# 0  [{'customer_id': 'CUST014', 'rating': 1, 'revi...
# 1  [{'customer_id': 'CUST082', 'rating': 4, 'revi...
# 2  [{'customer_id': 'CUST352', 'rating': 4, 'revi...
# 3  [{'customer_id': 'CUST261', 'rating': 3, 'revi...
# 4  [{'customer_id': 'CUST241', 'rating': 1, 'revi...
#
#                                        performance                last_updated
# 0    {'total_orders': 1407, 'cancelled_orders': 5}  2026-02-23T22:23:37.884927
# 1  {'total_orders': 151, 'cancelled_orders': None}  2026-02-22T12:23:37.885053
# 2     {'total_orders': 856, 'cancelled_orders': 8}  2026-02-24T15:23:37.885148
# 3     {'total_orders': 425, 'cancelled_orders': 8}  2026-02-20T23:23:37.885277
# 4   {'total_orders': 1403, 'cancelled_orders': 20}  2026-02-20T01:23:37.885400

# %%
from extract import extract
customers_df = extract("customers")
sellers_df   = extract("sellers")
orders_df = extract("orders")

# %%
customers_df.head(5)
# Out:
#   customer_id                                            profile  \
# 0     CUST001  {'name': 'Customer_1', 'email': 'customer1@exa...
# 1     CUST002  {'name': 'Customer_2', 'email': 'customer2@exa...
# 2     CUST003  {'name': 'Customer_3', 'email': 'customer3@exa...
# 3     CUST004  {'name': 'Customer_4', 'email': 'customer4@exa...
# 4     CUST005  {'name': 'Customer_5', 'email': 'customer5@exa...
#
#                                              address  \
# 0  {'current': {'street': 'Street 112', 'city': '...
# 1  {'current': {'street': 'Street 83', 'city': 'H...
# 2  {'current': {'street': 'Street 125', 'city': '...
# 3  {'current': {'street': 'Street 88', 'city': 'K...
# 4  {'current': {'street': 'Street 4', 'city': 'Ko...
#
#                                      payment_methods  \
# 0  [{'method': 'Credit Card', 'provider': 'ICICI'...
# 1  [{'method': 'Credit Card', 'provider': 'HDFC',...
# 2  [{'method': 'Debit Card', 'provider': 'SBI', '...
# 3  [{'method': 'UPI', 'provider': 'SBI', 'last_us...
# 4  [{'method': 'Debit Card', 'provider': 'HDFC', ...
#
#                  last_updated
# 0  2026-02-26T04:20:23.360672
# 1  2026-02-26T13:20:23.360728
# 2  2026-02-24T04:20:23.360752
# 3  2026-02-23T08:20:23.360773
# 4  2026-02-20T10:20:23.360790

# %%
sellers_df.head()
# Out:
#   seller_id                                     seller_profile  \
# 0   SELL001  {'name': 'Seller_1', 'business_type': 'Wholesa...
# 1   SELL002  {'name': 'Seller_2', 'business_type': None, 'j...
# 2   SELL003  {'name': 'Seller_3', 'business_type': 'Retail'...
# 3   SELL004  {'name': 'Seller_4', 'business_type': 'Retail'...
# 4   SELL005  {'name': 'Seller_5', 'business_type': 'Retail'...
#
#                                              address  \
# 0  {'street': 'Shop 155', 'city': 'Pune', 'state'...
# 1  {'street': 'Shop 280', 'city': 'Delhi', 'state...
# 2  {'street': 'Shop 298', 'city': 'Kolkata', 'sta...
# 3  {'street': 'Shop 83', 'city': 'Mumbai', 'state...
# 4  {'street': 'Shop 217', 'city': 'Pune', 'state'...
#
#                                             products  \
# 0  [{'product_id': 'PRD866', 'category': 'Electro...
# 1  [{'product_id': 'PRD528', 'category': 'Books',...
# 2  [{'product_id': 'PRD555', 'category': 'Clothin...
# 3  [{'product_id': 'PRD833', 'category': 'Books',...
# 4  [{'product_id': 'PRD831', 'category': 'Books',...
#
#                                              ratings  \
# 0  [{'customer_id': 'CUST014', 'rating': 1, 'revi...
# 1  [{'customer_id': 'CUST082', 'rating': 4, 'revi...
# 2  [{'customer_id': 'CUST352', 'rating': 4, 'revi...
# 3  [{'customer_id': 'CUST261', 'rating': 3, 'revi...
# 4  [{'customer_id': 'CUST241', 'rating': 1, 'revi...
#
#                                        performance                last_updated
# 0    {'total_orders': 1407, 'cancelled_orders': 5}  2026-02-23T22:23:37.884927
# 1  {'total_orders': 151, 'cancelled_orders': None}  2026-02-22T12:23:37.885053
# 2     {'total_orders': 856, 'cancelled_orders': 8}  2026-02-24T15:23:37.885148
# 3     {'total_orders': 425, 'cancelled_orders': 8}  2026-02-20T23:23:37.885277
# 4   {'total_orders': 1403, 'cancelled_orders': 20}  2026-02-20T01:23:37.885400

# %%
orders_df.head()
# Out:
#   order_id customer_id seller_id                  order_date order_status  \
# 0  ORD0001     CUST173   SELL068  2026-02-15T14:30:28.025493    DELIVERED
# 1  ORD0002     CUST110   SELL035  2026-02-11T14:30:28.025584    CANCELLED
# 2  ORD0003     CUST429   SELL017  2026-02-07T14:30:28.025646       PLACED
# 3  ORD0004     CUST344   SELL029  2026-02-11T14:30:28.025703       PLACED
# 4  ORD0005     CUST437   SELL056  2026-02-14T14:30:28.025751       PLACED
#
#                                                items  \
# 0  [{'product_id': 'PRD426', 'product_name': 'Clo...
# 1  [{'product_id': 'PRD134', 'product_name': 'Clo...
# 2  [{'product_id': 'PRD756', 'product_name': 'Clo...
# 3  [{'product_id': 'PRD915', 'product_name': 'Boo...
# 4  [{'product_id': 'PRD651', 'product_name': 'Clo...
#
#                                              payment  \
# 0  {'method': 'UPI', 'transaction_id': 'TXN564118...
# 1  {'method': 'UPI', 'transaction_id': 'TXN294309...
# 2  {'method': 'Credit Card', 'transaction_id': 'T...
# 3  {'method': 'UPI', 'transaction_id': 'TXN455540...
# 4  {'method': 'UPI', 'transaction_id': 'TXN680412...
#
#                                             shipping  order_total  \
# 0  {'delivery_partner': 'Delhivery', 'expected_de...     66057.93
# 1  {'delivery_partner': None, 'expected_delivery'...     70345.25
# 2  {'delivery_partner': 'Delhivery', 'expected_de...     26484.62
# 3  {'delivery_partner': 'Delhivery', 'expected_de...    125493.68
# 4  {'delivery_partner': 'Delhivery', 'expected_de...     54059.38
#
#                  last_updated
# 0  2026-02-17T05:30:28.025493
# 1  2026-02-12T06:30:28.025584
# 2  2026-02-08T01:30:28.025646
# 3  2026-02-13T06:30:28.025703
# 4  2026-02-15T03:30:28.025751

# %%
from transform import transform

# %%
dir(transform)
# Out:
# ['__annotate__',
#  '__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__getstate__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__type_params__']

# %%
customers_df = transform(customers_df)
customers_df.head(2)
# Out:
#   customer_id                last_updated       method provider   last_used  \
# 0     CUST001  2026-02-26T04:20:23.360672  Credit Card    ICICI  2026-02-06
# 1     CUST002  2026-02-26T13:20:23.360728  Credit Card     HDFC  2026-01-31
#
#   profile_name          profile_email profile_phone profile_status  \
# 0   Customer_1  customer1@example.com    9631006637         ACTIVE
# 1   Customer_2  customer2@example.com    9655021673       INACTIVE
#
#           profile_signup_date address_current_street address_current_city  \
# 0  2026-01-08T14:20:23.360704             Street 112            Hyderabad
# 1  2025-03-12T14:20:23.360736              Street 83            Hyderabad
#
#   address_current_state address_current_zip address_current_country
# 0             Telangana              827822                   India
# 1             Telangana              846888                   India

# %%
sellers_df_transform=transform(sellers_df)
sellers_df_transform.head(2)
# Out:
#   seller_id                last_updated product_id     category     price  \
# 0   SELL001  2026-02-23T22:23:37.884927     PRD866  Electronics  15109.81
# 1   SELL001  2026-02-23T22:23:37.884927     PRD866  Electronics  15109.81
#
#    stock customer_id  rating                 review review_date  \
# 0  183.0     CUST014       1  Auto generated review  2026-01-12
# 1  183.0     CUST181       2                    NaN  2026-02-06
#
#   seller_profile_name seller_profile_business_type seller_profile_joined_date  \
# 0            Seller_1                    Wholesale                 2024-04-04
# 1            Seller_1                    Wholesale                 2024-04-04
#
#   address_street address_city address_state address_zip address_country  \
# 0       Shop 155         Pune   Maharashtra      787212           India
# 1       Shop 155         Pune   Maharashtra      787212           India
#
#    performance_total_orders  performance_cancelled_orders
# 0                      1407                           5.0
# 1                      1407                           5.0

# %%
orders_df.head(2)
# Out:
#   order_id customer_id seller_id                  order_date order_status  \
# 0  ORD0001     CUST173   SELL068  2026-02-15T14:30:28.025493    DELIVERED
# 1  ORD0002     CUST110   SELL035  2026-02-11T14:30:28.025584    CANCELLED
#
#                                                items  \
# 0  [{'product_id': 'PRD426', 'product_name': 'Clo...
# 1  [{'product_id': 'PRD134', 'product_name': 'Clo...
#
#                                              payment  \
# 0  {'method': 'UPI', 'transaction_id': 'TXN564118...
# 1  {'method': 'UPI', 'transaction_id': 'TXN294309...
#
#                                             shipping  order_total  \
# 0  {'delivery_partner': 'Delhivery', 'expected_de...     66057.93
# 1  {'delivery_partner': None, 'expected_delivery'...     70345.25
#
#                  last_updated
# 0  2026-02-17T05:30:28.025493
# 1  2026-02-12T06:30:28.025584

# %%
orders_df_transform=transform(orders_df)
orders_df_transform.head(2)
# Out:
#   order_id customer_id seller_id                  order_date order_status  \
# 0  ORD0001     CUST173   SELL068  2026-02-15T14:30:28.025493    DELIVERED
# 1  ORD0001     CUST173   SELL068  2026-02-15T14:30:28.025493    DELIVERED
#
#    order_total                last_updated product_id product_name  quantity  \
# 0     66057.93  2026-02-17T05:30:28.025493     PRD426     Clothing         2
# 1     66057.93  2026-02-17T05:30:28.025493     PRD426     Clothing         1
#
#       price discount_type  discount_amount payment_method  \
# 0  12601.74          FLAT            200.0            UPI
# 1  12601.74          FLAT             50.0            UPI
#
#   payment_transaction_id payment_payment_status shipping_delivery_partner  \
# 0              TXN564118                SUCCESS                 Delhivery
# 1              TXN564118                SUCCESS                 Delhivery
#
#   shipping_expected_delivery
# 0                 2026-02-22
# 1                 2026-02-22
